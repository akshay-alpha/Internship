# %% [markdown]
# ## Problem Statement:
#
# ## E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
#
#
# ## Let us import all the necessary libraries

# %%
#to work on mathematical and statistical dataseets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### There are 2 datasheets which have the information regarding e-ratail factors, let us load and convert both datasheets from excel to dataframe

# %%
df = pd.read_excel('customer_retention_dataset.xlsx', 'datasheet')
coded = pd.read_excel('customer_retention_dataset.xlsx', 'codedsheet')

# %%
df.head()
# Out:
#    Gender          Age       Location  Pin_Code Shopping_since  \
# 0    Male  31-40 years          Delhi    110009  Above 4 years
# 1  Female  21-30 years          Delhi    110030  Above 4 years
# 2  Female  21-30 years  Greater Noida    201308      3-4 years
# 3    Male  21-30 years        Karnal     132001      3-4 years
# 4  Female  21-30 years     Bangalore     530068      2-3 years
#
#    Purchase_frequency  Internet_access Device_name Screen_size  \
# 0         31-40 times          Dial-up     Desktop      Others
# 1  41 times and above            Wi-Fi  Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone  4.7 inches
#
#                       OS  ... time_in_promotion_sales_period  \
# 0  Window/windows Mobile  ...                      Amazon.in
# 1                IOS/Mac  ...        Amazon.in, Flipkart.com
# ...

# %%
coded
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
print(df.shape)
# Out:
# (269, 71)

# %%
df.columns()
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# ## Exploratory Data Analysis:
#
# Let us analyse the data how can we extract some good information about the customer behavior based on available user data. Let us blend the data as per our requirement for the analysis using different tricks and techniques solving the problem statememt at the end.
#
# ### 1. We can see there are too long column names for both sheets, it will be inconvenient to readout all the names since they consume lot of spaces.
# ### 2. We need to alter all the column names into easy and user friendly names.
#
# ### 3. Let us rename the column names into new names.
#
# 1. Gender of respondent: Gender,
# 2. How old are you?: Age
# 3. Which city do you shop online from?: Location
# 4. What is the Pin Code of where you shop online from?: Pin_Code
# 5. Since How Long You are Shopping Online ?: Shopping_since
# 6. How many times you have made an online purchase in the past 1 year?: Purchase_frequency
# 7. How do you access the internet while shopping on-line?: Internet_access
# 8. Which device do you use to access the online shopping?: Device_name
# 9. What is the screen size of your mobile device?: Screen_size
# 10. What is the operating system (OS) of your device?:  OS
# 11. What browser do you run on your device to access the website?: Browser
# 12. Which channel did you follow to arrive at your favorite online store for the first time? : Channel_name
# 13. After first visit, how do you reach the online retail store?: After_first_visit
# 14. How much time do you explore the e- retail store before making a purchase decision?: explore_frequency
# 15. What is your preferred payment Option?: Payment_option
# 16. How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?: Abandon_frequency
# 17. Why did you abandon the “Bag”, “Shopping Cart”?: Abandon_reason
# 18. The content on the website must be easy to read and understand": Ease_of_reading
# 19. Information on similar product to the one highlighted  is important for product comparison: Similar_prod_info
# 20. Complete information on listed seller and product being offered is important for purchase decision: Complete_info
# 21. All relevant information on listed products must be stated clearly: Clear_Relavant_info
# 22. Ease of navigation in website: Ease_of_navigation
# 23. Loading and processing speed: Loading_speed
# 24. User friendly Interface of the website: User_friendliness
# 25. Convenient Payment methods: Convenient_payment
# 26. Trust that the online retail store will fulfill its part of the transaction at the stipulated time: Trust_of_transaction
# 27. Empathy (readiness to assist with queries) towards the customers: Empathy
# 28. Being able to guarantee the privacy of the customer: Customer_privacy
# 29. Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.): Customer_friendly
# 30. Online shopping gives monetary benefit and discounts: Benefits/discounts
# 31. Enjoyment is derived from shopping online: Shopping_Enjoyment
# 32. Shopping online is convenient and flexible: Convenience/flexibility
# 33. Return and replacement policy of the e-tailer is important for purchase decision: Return/Replacement
# 34. Gaining access to loyalty programs is a benefit of shopping online: Loyalty_programs
# 35. Displaying quality Information on the website improves satisfaction of customers: Quality_info_on_website
# 36. User derive satisfaction while shopping on a good quality website or application: Satisfaction_by_good_website
# 37. Net Benefit derived from shopping online can lead to users satisfaction: Net_benefit_by_shopping
# 38. User satisfaction cannot exist without trust: Trust
# 39. Offering a wide variety of listed product in several category: Category_of_products
# 40. Provision of complete and relevant product information: Complete_Product_info
# 41. Monetary savings: Savings
# 42. The Convenience of patronizing the online retailer: Patronizing_retailer
# 43. Shopping on the website gives you the sense of adventure: Sense_of_adventure
# 44. Shopping on your preferred e-tailer enhances your social status: Social_status
# 45. You feel gratification shopping on your favorite e-tailer: Gratification
# 46. Shopping on the website helps you fulfill certain roles: Role_fullfillment
# 47. Getting value for money spent: Value_for_money
# 48. From the following, tick any (or all) of the online retailers you have shopped from: Online_retailers_shopped
# 49. Easy to use website or application: Website/application Ease
# 50. Visual appealing web-page layout: Web-page_layout
# 51. Wild variety of product on offer: Variety_of_product
# 52. Complete, relevant description information of products: Complete/relavant info
# 53. Fast loading website speed of website and application: Speed_of_website
# 54. Reliability of the website or application: Reliability_of_application
# 55. Quickness to complete purchase: Quickness
# 56. Availability of several payment options: Payment_options
# 57. Speedy order delivery: Delivery_Speed
# 58. Privacy of customers’ information: Privacy_of_customer_info
# 59. Security of customer financial information: Financial_info_security
# 60. Perceived Trustworthiness: Trustworthiness
# 61. Presence of online assistance through multi-channel: Online_assistance
# 62. Longer time to get logged in (promotion, sales period): time_in_promotion_sales_period
# 63. Longer time in displaying graphics and photos (promotion, sales period): Displaying_graphs_time
# 64. Late declaration of price (promotion, sales period): Declaration_of_price
# 65. Longer page loading time (promotion, sales period): Loading_time
# 66. Limited mode of payment on most products (promotion, sales period): Limited_mode_of_payment
# 67. Longer delivery period: Delivery_period
# 68. Change in website/Application design: Design_change
# 69. Frequent disruption when moving from one page to another: Disruption_frequency
# 70. Website is as efficient as before: Efficiency_comparison
# 71. Which of the Indian online retailer would you recommend to a friend: Recomendation_of_online_retailer

# %%
#we have loaded all the names of columns as per requirement and stored in a list
column_names= ['Gender','Age','Location','Pin_Code','Shopping_since','Purchase_frequency','Internet_access','Device_name','Screen_size','OS','Browser','Channel_name','After_first_visit',
'explore_frequency','Payment_option','Abandon_frequency','Abandon_reason','Ease_of_reading','Similar_prod_info','Complete_info','Clear_Relavant_info','Ease_of_navigation','Loading_speed',
'User_friendliness','Convenient_payment','Trust_of_transaction','Empathy','Customer_privacy','Customer_friendly','Benefits/discounts','Shopping_Enjoyment','Convenience/flexibility','Return/Replacement',
'Loyalty_programs','Quality_info_on_website','Satisfaction_by_good_website','Net_benefit_by_shopping','Trust','Category_of_products','Complete_Product_info','Savings','Patronizing_retailer','Sense_of_adventure',
'Social_status','Gratification','Role_fullfillment','Value_for_money','Online_retailers_shopped','Website/application Ease','Web-page_layout','Variety_of_product','Complete/relavant info','Speed_of_website',
'Reliability_of_application','Quickness','Payment_options','Delivery_Speed','Privacy_of_customer_info','Financial_info_security','Trustworthiness','Online_assistance','time_in_promotion_sales_period',
'Displaying_graphs_time','Declaration_of_price','Loading_time','Limited_mode_of_payment','Delivery_period','Design_change','Disruption_frequency','Efficiency_comparison','Recomendation_of_online_retailer'
]

#assigning column names from the list to datframe
df.columns = column_names

# %%
#checking the names of columns changed.
df.columns
# Out:
# Index(['Gender', 'Age', 'Location', 'Pin_Code', 'Shopping_since',
#        'Purchase_frequency', 'Internet_access', 'Device_name', 'Screen_size',
#        'OS', 'Browser', 'Channel_name', 'After_first_visit',
#        'explore_frequency', 'Payment_option', 'Abandon_frequency',
#        'Abandon_reason', 'Ease_of_reading', 'Similar_prod_info',
#        'Complete_info', 'Clear_Relavant_info', 'Ease_of_navigation',
#        'Loading_speed', 'User_friendliness', 'Convenient_payment',
#        'Trust_of_transaction', 'Empathy', 'Customer_privacy',
#        'Customer_friendly', 'Benefits/discounts', 'Shopping_Enjoyment',
#        'Convenience/flexibility', 'Return/Replacement', 'Loyalty_programs',
#        'Quality_info_on_website', 'Satisfaction_by_good_website',
#        'Net_benefit_by_shopping', 'Trust', 'Category_of_products',
#        'Complete_Product_info', 'Savings', 'Patronizing_retailer',
#        'Sense_of_adventure', 'Social_status', 'Gratification',
# ...

# %%
#we can see that names of columns have been changed as per requirement
df
# Out:
#      Gender                 Age       Location  Pin_Code Shopping_since  \
# 0      Male         31-40 years          Delhi    110009  Above 4 years
# 1    Female         21-30 years          Delhi    110030  Above 4 years
# 2    Female         21-30 years  Greater Noida    201308      3-4 years
# 3      Male         21-30 years        Karnal     132001      3-4 years
# 4    Female         21-30 years     Bangalore     530068      2-3 years
# ..      ...                 ...            ...       ...            ...
# 264  Female         21-30 years          Solan    173212      1-2 years
# 265  Female         31-40 years      Ghaziabad    201008      1-2 years
# 266  Female         41-50 yaers     Bangalore     560010      2-3 years
# 267  Female  Less than 20 years          Solan    173229      2-3 years
# 268  Female         41-50 yaers      Ghaziabad    201009      2-3 years
#
#      Purchase_frequency  Internet_access Device_name Screen_size  \
# ...

# %%
#let us check the data types for all attributes in datasets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Gender                            269 non-null    object
#  1   Age                               269 non-null    object
#  2   Location                          269 non-null    object
#  3   Pin_Code                          269 non-null    int64
#  4   Shopping_since                    269 non-null    object
#  5   Purchase_frequency                269 non-null    object
#  6   Internet_access                   269 non-null    object
#  7   Device_name                       269 non-null    object
#  8   Screen_size                       269 non-null    object
#  9   OS                                269 non-null    object
#  10  Browser                           269 non-null    object
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# Gender                              0
# Age                                 0
# Location                            0
# Pin_Code                            0
# Shopping_since                      0
#                                    ..
# Delivery_period                     0
# Design_change                       0
# Disruption_frequency                0
# Efficiency_comparison               0
# Recomendation_of_online_retailer    0
# Length: 71, dtype: int64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.heatmap(df.isnull())
plt.title('Graph showing if any null values')
plt.show()

# %% [markdown]
# 1. We see that almost all the attributes available are categorical datatypes and we need to check how individual attributes relates each other.
# 2. There are no null values available in the dataset, we are good to go for data visualization techniques
# 3. Let us first see how many unique values are available for each attributes

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('~:'*50)
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64
# ~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64
# ~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: Location, dtype: int64
# ~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:~:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# ...

# %% [markdown]
# ## Data Visualization:
# Let us visualize the customer details attributes in test data sets

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Gender'], palette='CMRmap')
print('Percentage Gender Ratio: \n',(df['Gender'].value_counts())/269*100)
plt.title("Graph showing number of male and female customer")
plt.show()
# Out:
# Percentage Gender Ratio:
#  Female    67.286245
# Male      32.713755
# Name: Gender, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Age'], palette='Pastel2_r')
print('Percentage Age Ratio of differnt class: \n',(df['Age'].value_counts())/269*100)
plt.title("Graph showing age of customer")
plt.xticks(rotation=10)
plt.show()
# Out:
# Percentage Age Ratio of differnt class:
#  31-40 years           30.111524
# 21-30 years           29.368030
# 41-50 yaers           26.022305
# Less than 20 years     7.434944
# 51 years and above     7.063197
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Shopping_since'], palette='YlGn')
print('How Long customer is Shopping Online : \n',(df['Shopping_since'].value_counts())/269*100)
plt.title("Graph showing customer shopping ")
plt.show()
# Out:
# How Long customer is Shopping Online :
#  Above 4 years       36.431227
# 2-3 years           24.163569
# 3-4 years           17.472119
# Less than 1 year    15.985130
# 1-2 years            5.947955
# Name: Shopping_since, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Purchase_frequency'], palette='Spectral')
print('Purchase_frequency of customer in 1 year : \n',(df['Purchase_frequency'].value_counts())/269*100)
plt.title("Graph showing customer Purchase_frequency for 1 year")
plt.xticks(rotation=20)
plt.show()
# Out:
# Purchase_frequency of customer in 1 year :
#  Less than 10 times    42.379182
# 31-40 times           23.420074
# 41 times and above    17.472119
# 11-20 times           10.780669
# 21-30 times            3.717472
# 42 times and above     2.230483
# Name: Purchase_frequency, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Internet_access'], palette='Set2')
print('Internet_access of customer while browsing : \n',(df['Internet_access'].value_counts())/269*100)
plt.title("Graph showing customer Internet_access while using website/application")
plt.show()
# Out:
# Internet_access of customer while browsing :
#  Mobile internet    52.788104
# Wi-Fi              28.252788
# Mobile Internet    17.472119
# Dial-up             1.486989
# Name: Internet_access, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Device_name'], palette='Reds_r')
print('Device used by customer while browsing : \n',(df['Device_name'].value_counts())/269*100)
plt.title("Graph showing customer device while using website/application")
plt.show()
# Out:
# Device used by customer while browsing :
#  Smartphone    52.416357
# Laptop        31.970260
# Desktop       11.152416
# Tablet         4.460967
# Name: Device_name, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Screen_size'], palette='PiYG_r')
print('Screen_size of mobile used by customer while browsing : \n',(df['Screen_size'].value_counts())/269*100)
plt.title("Graph showing customer device Screen_size while using website/application")
plt.show()
# Out:
# Screen_size of mobile used by customer while browsing :
#  Others        49.814126
# 5.5 inches    36.802974
# 4.7 inches    10.780669
# 5 inches       2.602230
# Name: Screen_size, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['OS'], palette='cividis')
print('OS of mobile used by customer while browsing : \n',(df['OS'].value_counts())/269*100)
plt.title("Graph showing customer device OS while using website/application")
plt.show()
# Out:
# OS of mobile used by customer while browsing :
#  Window/windows Mobile    45.353160
# Android                  31.598513
# IOS/Mac                  23.048327
# Name: OS, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Browser'], palette='flare')
print('Browser used by customer while browsing : \n',(df['Browser'].value_counts())/269*100)
plt.title("Graph showing customer Browser while using website/application")
plt.show()
# Out:
# Browser used by customer while browsing :
#  Google chrome      80.297398
# Safari             14.869888
# Opera               2.973978
# Mozilla Firefox     1.858736
# Name: Browser, dtype: float64

# %%
plt.figure(figsize=(8,6), facecolor='white')
sns.countplot(x=df['Channel_name'], palette='gist_earth_r')
print('Channel used by customer while browsing : \n',(df['Channel_name'].value_counts())/269*100)
plt.title("Graph showing customer Channel used while using website/application")
plt.show()
# Out:
# Channel used by customer while browsing :
#  Search Engine        85.501859
# Content Marketing     7.434944
# Display Adverts       7.063197
# Name: Channel_name, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['Location'], palette='Spectral')
print('Location of customer in 1 year : \n',(df['Location'].value_counts())/269*100)
plt.title("Graph showing customer Location")
plt.show()
# Out:
# Location of customer in 1 year :
#  Delhi            21.561338
# Greater Noida    15.985130
# Noida            14.869888
# Bangalore        13.754647
# Karnal           10.037175
# Ghaziabad         6.691450
# Solan             6.691450
# Gurgaon           4.460967
# Merrut            3.345725
# Moradabad         1.858736
# Bulandshahr       0.743494
# Name: Location, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['After_first_visit'], palette='hsv_r')
print('How did customer reach after_first_visit : \n',(df['After_first_visit'].value_counts())/269*100)
plt.title("Graph showing which media customer used After_first_visit ")
plt.show()
# Out:
# How did customer reach after_first_visit :
#  Search Engine      32.342007
# Via application    31.970260
# Direct URL         26.022305
# E-mail              6.691450
# Social Media        2.973978
# Name: After_first_visit, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['explore_frequency'], palette='Spectral')
print('How much time did customer explore : \n',(df['explore_frequency'].value_counts())/269*100)
plt.title("Graph showing time, customer explore before making a purchase decision ")
plt.show()
# Out:
# How much time did customer explore :
#  more than 15 mins    45.724907
# 6-10 mins            26.394052
# 11-15 mins           17.100372
# Less than 1 min       5.576208
# 1-5 mins              5.204461
# Name: explore_frequency, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['Payment_option'], palette='gnuplot2')
print('Mode of payment customer used : \n',(df['Payment_option'].value_counts())/269*100)
plt.title("Graph showing Payment_option making a payment ")
plt.show()
# Out:
# Mode of payment customer used :
#  Credit/Debit cards                    55.018587
# Cash on delivery (CoD)                28.252788
# E-wallets (Paytm, Freecharge etc.)    16.728625
# Name: Payment_option, dtype: float64

# %% [markdown]
# ## Observations:
# 1. The number of women customer shopping online is higher than that of men, 68% of customer are Womens.
# 2. Nearly 31-40 aged people are seen to be shopping online the most. People aging from 21-50 makes around 85% of total customers who are shopping online.
# 3. People shopping since 4 years make nearly 36-40% of customers, and customer shopping 80% of total customer are shopping since more  than 2 years.
# * High number of people have voted to shop less than 10 times in a year. Hence this category of data need to be focused more in order to improve action and retention.
#
# 4. 70% of people using the application make use of Mobile Internet to shop online.
# 5. Customer shopping from mobile comprise of more than 50% of total customers.
# 6. 80% percent customer accessing online shopping website are Chrome users. We can say that chrome provides user friendly interface which is liked by most of users.
# 7. Channel followed by user to arrive at the favorite online store for the first time is Search_engine
# 8. Highest online shopping is done from Delhi region with 21% of total customes, followed by Greater Noida, and Least is Bulandshahr.
# 9. 90% of Customer has reached the websites after first visit through search engine, application and company URL.
# 10. Most of the customer has spent more than 15 minutes before making the decision of purchase.
# 11. Customre feels ease of using Debit/Credit cards and COD as mode of payment while making an order. This may be due to availability of any cashback offers or customer see reliabilty in COD payment.
#
# ### Let us further analyse other attributes which are related to e-commerce companies customer feedback:

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['Abandon_frequency'], palette='magma_r')
print('Number of times customer cancelled the products in bag : \n',(df['Abandon_frequency'].value_counts())/269*100)
plt.title("Graph showing abandon frequency ")
plt.show()
# Out:
# Number of times customer cancelled the products in bag :
#  Sometimes          63.568773
# Never              17.843866
# Frequently         13.011152
# Very frequently     5.576208
# Name: Abandon_frequency, dtype: float64

# %%
plt.figure(figsize=(15,6), facecolor='white')
sns.countplot(x=df['Abandon_reason'], palette='gnuplot2')
print('Reason for customer cancelled the products in bag : \n',(df['Abandon_reason'].value_counts())/269*100)
plt.title("Graph showing the reason for high abandon frequency ")
plt.show()
# Out:
# Reason for customer cancelled the products in bag :
#  Better alternative offer        49.442379
# Promo code not applicable       20.074349
# Change in price                 13.754647
# Lack of trust                   11.524164
# No preferred mode of payment     5.204461
# Name: Abandon_reason, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Ease_of_reading'], palette='gist_stern')
print('The content on the website must be easy to read : \n',(df['Ease_of_reading'].value_counts())/269*100)
plt.title("Graph showing The content on the website's ease to read ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Similar_prod_info'], palette='gist_ncar')
print('\n Information on similar product to the one highlighted : \n',(df['Similar_prod_info'].value_counts())/269*100)
plt.title("Graph showing the information on similar product to the one highlighted  ")

plt.show()
# Out:
# The content on the website must be easy to read :
#  Strongly agree (5)       60.966543
# Agree (4)                29.739777
# Strongly disagree (1)     6.691450
# Indifferent (3)           2.602230
# Name: Ease_of_reading, dtype: float64
#
#  Information on similar product to the one highlighted :
#  Strongly agree (5)    43.122677
# Agree (4)             34.200743
# Indifferent (3)       15.985130
# Dis-agree (2)          6.691450
# Name: Similar_prod_info, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Complete_info'], palette='gist_stern')
plt.xticks(rotation=20)
print('Complete information on listed seller and product being offered : \n',(df['Complete_info'].value_counts())/269*100)
plt.title("Graph showing the complete information on listed seller and product being offered ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Clear_Relavant_info'], palette='gist_ncar')
plt.xticks(rotation=20)
print('\n All relevant information on listed products  : \n',(df['Clear_Relavant_info'].value_counts())/269*100)
plt.title("Graph showing if all relevant information on listed products ")

plt.show()
# Out:
# Complete information on listed seller and product being offered :
#  Agree (4)                37.546468
# Strongly agree (5)       32.342007
# Indifferent (3)          19.330855
# Dis-agree (2)             6.691450
# Strongly disagree (1)     4.089219
# Name: Complete_info, dtype: float64
#
#  All relevant information on listed products  :
#  Agree (4)                49.070632
# Strongly agree (5)       39.776952
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Name: Clear_Relavant_info, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Ease_of_navigation'], palette='mako_r')
plt.xticks(rotation=20)
print('Ease of navigation in website : \n',(df['Ease_of_navigation'].value_counts())/269*100)
plt.title("Graph showing the ease of navigation in website ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Loading_speed'], palette='nipy_spectral')
plt.xticks(rotation=20)
print('\n Loading and processing speed   : \n',(df['Loading_speed'].value_counts())/269*100)
plt.title("Graph showing Loading and processing speed ")

plt.show()
# Out:
# Ease of navigation in website :
#  Strongly agree (5)       52.416357
# Agree (4)                39.033457
# Strongly disagree (1)     6.691450
# Dis-agree (2)             1.858736
# Name: Ease_of_navigation, dtype: float64
#
#  Loading and processing speed   :
#  Strongly agree (5)       42.750929
# Agree (4)                41.635688
# Dis-agree (2)             6.691450
# Indifferent (3)           4.460967
# Strongly disagree (1)     4.460967
# Name: Loading_speed, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['User_friendliness'], palette='mako_r')
plt.xticks(rotation=20)
print('User friendly Interface of the website  : \n',(df['User_friendliness'].value_counts())/269*100)
plt.title("Graph showing the user friendly Interface of the website ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Convenient_payment'], palette='nipy_spectral')
plt.xticks(rotation=20)
print('\n Convenient Payment methods : \n',(df['Convenient_payment'].value_counts())/269*100)
plt.title("Graph showing the convenient Payment methods ")

plt.show()
# Out:
# User friendly Interface of the website  :
#  Strongly agree (5)       70.260223
# Agree (4)                16.728625
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Indifferent (3)           1.858736
# Name: User_friendliness, dtype: float64
#
#  Convenient Payment methods :
#  Strongly agree (5)    59.107807
# Agree (4)             29.739777
# Dis-agree (2)         11.152416
# Name: Convenient_payment, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Trust_of_transaction'], palette='ocean')
plt.xticks(rotation=20)
print('Trust that the online retail store will fulfill its part of the transaction  : \n',(df['Trust_of_transaction'].value_counts())/269*100)
plt.title("Graph showing the trust of transactin from retailer side ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Empathy'], palette='plasma')
plt.xticks(rotation=20)
print('\n Empathy (readiness to assist with queries) towards the customers : \n',(df['Empathy'].value_counts())/269*100)
plt.title("Graph showing the empathy towards customer ")

plt.show()
# Out:
# Trust that the online retail store will fulfill its part of the transaction  :
#  Strongly agree (5)    52.416357
# Agree (4)             31.970260
# Disagree (2)          11.152416
# indifferent  (3)       4.460967
# Name: Trust_of_transaction, dtype: float64
#
#  Empathy (readiness to assist with queries) towards the customers :
#  Strongly agree (5)       72.118959
# Agree (4)                15.613383
# Strongly disagree (1)     6.691450
# indifferent (3)           5.576208
# Name: Empathy, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Customer_privacy'], palette='prism_r')
plt.xticks(rotation=20)
print('Being able to guarantee the privacy of the customer -  : \n',(df['Customer_privacy'].value_counts())/269*100)
plt.title("Graph showing the guarantee of customer privacy ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Customer_friendly'], palette='rainbow_r')
plt.xticks(rotation=20)
print('\n Responsiveness, availability of several communication channels : \n',(df['Customer_friendly'].value_counts())/269*100)
plt.title("Graph showing the responsiveness ")

plt.show()
# Out:
# Being able to guarantee the privacy of the customer -  :
#  Strongly agree (5)    68.773234
# Agree (4)             21.561338
# indifferent (3)        9.665428
# Name: Customer_privacy, dtype: float64
#
#  Responsiveness, availability of several communication channels :
#  Strongly agree (5)       55.390335
# Agree (4)                34.944238
# indifferent (3)           5.576208
# Strongly disagree (1)     4.089219
# Name: Customer_friendly, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Benefits/discounts'], palette='spring')
plt.xticks(rotation=20)
print(' Online shopping gives monetary benefit and discounts -  : \n',(df['Benefits/discounts'].value_counts())/269*100)
plt.title("Graph showing the benefit and discounts provided by online shopping ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Shopping_Enjoyment'], palette='rainbow_r')
plt.xticks(rotation=20)
print('\n Enjoyment is derived from shopping online : \n',(df['Shopping_Enjoyment'].value_counts())/269*100)
plt.title("Graph showing if customer is enjoying from shopping online ")

plt.show()
# Out:
#  Online shopping gives monetary benefit and discounts -  :
#  Strongly agree (5)       39.033457
# Agree (4)                31.598513
# indifferent (3)          18.587361
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.089219
# Name: Benefits/discounts, dtype: float64
#
#  Enjoyment is derived from shopping online :
#  Strongly agree (5)       31.970260
# indifferent (3)          27.881041
# Agree (4)                21.933086
# Strongly disagree (1)    11.152416
# Dis-agree (2)             7.063197
# Name: Shopping_Enjoyment, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Convenience/flexibility'], palette='summer')
plt.xticks(rotation=20)
print(' Is shopping online is convenient and flexible -  : \n',(df['Convenience/flexibility'].value_counts())/269*100)
plt.title("Graph showing convenience and flexibilty of shopping ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Return/Replacement'], palette='tab10')
plt.xticks(rotation=20)
print('\n Return and replacement policy of the e-tailer is important for purchase decision : \n',(df['Return/Replacement'].value_counts())/269*100)
plt.title("Graph showing if customer is having return and replacement from shopping online ")

plt.show()
# Out:
#  Is shopping online is convenient and flexible -  :
#  Strongly agree (5)    54.275093
# Agree (4)             28.996283
# indifferent (3)       12.267658
# Dis-agree (2)          4.460967
# Name: Convenience/flexibility, dtype: float64
#
#  Return and replacement policy of the e-tailer is important for purchase decision :
#  Strongly agree (5)    73.605948
# Agree (4)             18.959108
# Dis-agree (2)          7.434944
# Name: Return/Replacement, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Loyalty_programs'], palette='summer')
plt.xticks(rotation=20)
print(' Is Gaining access to loyalty programs a benefit of shopping online : \n',(df['Loyalty_programs'].value_counts())/269*100)
plt.title("Graph showing customer gaining access to loyalty programs ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Quality_info_on_website'], palette='tab10')
plt.xticks(rotation=20)
print('\n Displaying quality Information on the website improves satisfaction of customers  : \n',(df['Quality_info_on_website'].value_counts())/269*100)
plt.title("Graph showing if customer is getting quality information ")

plt.show()
# Out:
#  Is Gaining access to loyalty programs a benefit of shopping online :
#  Strongly agree (5)       42.750929
# Agree (4)                23.791822
# indifferent (3)          23.791822
# Dis-agree (2)             5.576208
# Strongly disagree (1)     4.089219
# Name: Loyalty_programs, dtype: float64
#
#  Displaying quality Information on the website improves satisfaction of customers  :
#  Strongly agree (5)    49.442379
# Agree (4)             29.739777
# indifferent (3)       20.817844
# Name: Quality_info_on_website, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Satisfaction_by_good_website'], palette='terrain')
plt.xticks(rotation=20)
print(' Is User deriving satisfaction while shopping on a good quality website or application : \n',(df['Satisfaction_by_good_website'].value_counts())/269*100)
plt.title("Graph showing customer satisfaction_by_good_website ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Net_benefit_by_shopping'], palette='tab20_r')
plt.xticks(rotation=20)
print('\n Net Benefit derived from shopping online can lead to users satisfaction: \n',(df['Net_benefit_by_shopping'].value_counts())/269*100)
plt.title("Graph showing if customer is getting Net_benefit_by_shopping ")

plt.show()
# Out:
#  Is User deriving satisfaction while shopping on a good quality website or application :
#  Strongly agree (5)    65.055762
# Agree (4)             31.970260
# Dis-agree (2)          2.973978
# Name: Satisfaction_by_good_website, dtype: float64
#
#  Net Benefit derived from shopping online can lead to users satisfaction:
#  Strongly agree (5)    60.966543
# Agree (4)             20.074349
# indifferent (3)       14.869888
# Dis-agree (2)          4.089219
# Name: Net_benefit_by_shopping, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Category_of_products'], palette='twilight_r')
plt.xticks(rotation=20)
print(' Is online shopping offering a wide variety of listed product in several category : \n',(df['Category_of_products'].value_counts())/269*100)
plt.title("Graph showing Category_of_products ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Complete_Product_info'], palette='turbo_r')
plt.xticks(rotation=20)
print('\n Provision of complete and relevant product information: \n',(df['Complete_Product_info'].value_counts())/269*100)
plt.title("Graph showing if customer is getting Complete and Product_info ")

plt.show()
# Out:
#  Is online shopping offering a wide variety of listed product in several category :
#  Strongly agree (5)    41.263941
# Agree (4)             34.944238
# indifferent (3)       21.189591
# Dis-agree (2)          2.602230
# Name: Category_of_products, dtype: float64
#
#  Provision of complete and relevant product information:
#  Strongly agree (5)    50.185874
# Agree (4)             36.431227
# indifferent (3)       11.524164
# Disagree (2)           1.858736
# Name: Complete_Product_info, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Savings'], palette='vlag')
plt.xticks(rotation=20)
print(' Total Monetary savings : \n',(df['Savings'].value_counts())/269*100)
plt.title("Graph showing Monetary savings ")

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Patronizing_retailer'], palette='winter_r')
plt.xticks(rotation=20)
print('\n The Convenience of patronizing the online retailer: \n',(df['Patronizing_retailer'].value_counts())/269*100)
plt.title("Graph showing the Convenience of patronizing the online retailer ")

plt.show()
# Out:
#  Total Monetary savings :
#  Strongly agree (5)    55.018587
# Agree (4)             27.881041
# Disagree (2)          11.524164
# indifferent (3)        5.576208
# Name: Savings, dtype: float64
#
#  The Convenience of patronizing the online retailer:
#  Agree (4)             51.301115
# indifferent (3)       28.624535
# Strongly agree (5)    20.074349
# Name: Patronizing_retailer, dtype: float64

# %% [markdown]
# ## Observations:
#
# #### 1. 65% of Customers have voted that they abandon the products in bags "Sometimes".
# #### 2. More than 50 % of customer has abandoned the bag as they got another alternative, but nearly 30% of customer abandoned due to lack of trust and not available mode of payment, by focusing on providing good benefits and multiple mode of payments may reduce these columns into 0.
# #### 3. 90% of customer agree or Strongly agree that the content on the website is be easy to read and understand. Further improve ment can be directly made by asking customer feedback and taking hypthesis if that decision holds good for all population.
# #### 4. 80% of customer agreee that information on similar product to the one highlighted is important for product comparison.
# #### 5. 75% of customer agree that if product is to be bough by most of customer then, complete information on listed seller and product being offered is important for purchase decision.
# #### 6. 90% agree that to make a clear decision on purchase of product all the relevant information on listed products must be stated clearly
# #### 7. It is evident that companies website should have better ease of navigation in website to make more customer interaction and customer activation.
# #### 8. The website/Application should have better loading and processing speed, agreed by 85% of customers.
# #### 9. Website having user friendly Interface will have high customer interaction, strongly agreed by 70%
# #### 10. 60% of customer strongly agree that comapanies have convenient mode of payments.
# #### 11. Customer strongly agree that customer care executives behave with empathy towards customer problems/issues.
# #### 12. Customer have strongly agreed that customer data privacy is guranteed and Responsiveness is more customer friendly.

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Sense_of_adventure'], palette='vlag')
plt.xticks(rotation=20)
print(' Sense_of_adventure : \n',(df['Sense_of_adventure'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Social_status'], palette='winter_r')
plt.xticks(rotation=20)
print('\n Does Shopping on your preferred e-tailer enhances social status: \n',(df['Social_status'].value_counts())/269*100)

plt.show()
# Out:
#  Sense_of_adventure :
#  Agree (4)                37.546468
# indifferent (3)          21.933086
# Strongly agree (5)       20.074349
# Dis-agree (2)            18.587361
# Strongly disagree (1)     1.858736
# Name: Sense_of_adventure, dtype: float64
#
#  Does Shopping on your preferred e-tailer enhances social status:
#  indifferent (3)          37.174721
# Agree (4)                21.933086
# Strongly agree (5)       17.843866
# Strongly disagree (1)    12.267658
# Dis-agree (2)            10.780669
# Name: Social_status, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Gratification'], palette='OrRd')
plt.xticks(rotation=20)
print(' Feel of gratification shopping on the favorite e-tailer : \n',(df['Gratification'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Role_fullfillment'], palette='Oranges')
plt.xticks(rotation=20)
print('\n Shopping on the website helps you fulfill certain roles: \n',(df['Role_fullfillment'].value_counts())/269*100)

plt.show()
# Out:
#  Feel of gratification shopping on the favorite e-tailer :
#  indifferent (3)          37.546468
# Strongly agree (5)       24.163569
# Agree (4)                23.420074
# Disagree (2)              8.178439
# Strongly disagree (1)     6.691450
# Name: Gratification, dtype: float64
#
#  Shopping on the website helps you fulfill certain roles:
#  Agree (4)                32.713755
# indifferent (3)          32.713755
# Strongly agree (5)       14.126394
# Strongly disagree (1)    12.267658
# Dis-agree (2)             8.178439
# Name: Role_fullfillment, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Value_for_money'], palette='CMRmap')
plt.xticks(rotation=20)
print('Getting value for money spent: \n',(df['Value_for_money'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Online_retailers_shopped'], palette='Greens')
plt.xticks(rotation=80)
print('\n online retailers customer have shopped from: \n',(df['Online_retailers_shopped'].value_counts())/269*100)

plt.show()
# Out:
# Getting value for money spent:
#  Agree (4)             55.390335
# Strongly agree (5)    30.483271
# indifferent (3)       14.126394
# Name: Value_for_money, dtype: float64
#
#  online retailers customer have shopped from:
#  Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30.483271
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16.356877
# Amazon.in, Flipkart.com                                         11.895911
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                10.780669
# Amazon.in, Flipkart.com, Snapdeal.com                           10.037175
# Amazon.in, Paytm.com, Myntra.com                                 7.434944
# Amazon.in                                                        5.947955
# Amazon.in, Paytm.com                                             4.460967
# Amazon.in, Flipkart.com, Paytm.com                               2.602230
# Name: Online_retailers_shopped, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Website/application Ease'], palette='CMRmap')
plt.xticks(rotation=90)
print('Easy to use website or application : \n',(df['Website/application Ease'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Online_retailers_shopped'], palette='Greens')
plt.xticks(rotation=90)
print('\n online retailers customer have shopped from: \n',(df['Online_retailers_shopped'].value_counts())/269*100)

plt.show()
# Out:
# Easy to use website or application :
#  Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    23.791822
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16.356877
# Amazon.in, Flipkart.com                                         16.356877
# Amazon.in                                                       10.780669
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                 8.178439
# Amazon.in, Paytm.com, Myntra.com                                 7.434944
# Amazon.in, Flipkart.com, Myntra.com                              7.063197
# Paytm.com                                                        4.460967
# Flipkart.com                                                     2.973978
# Amazon.in, Paytm.com                                             2.602230
# Name: Website/application Ease, dtype: float64
#
#  online retailers customer have shopped from:
#  Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30.483271
# ...

# %% [markdown]
# ## Customers have strongly agreed the following below points:
# #### 1. Benefits and Discounts are provided by online shopping retailers, and they have enjoyed the shopping experience.
# #### 2. Convenience and Flexibility in shopping online, Return/Replacements are provided for the products purchased.
# #### 3. Loyalty benefit programms are benefits for online shopping,
# #### 4. Information provided on website have quality information of products and improves customer satisfaction.
# #### 5. Net benefits by online shopping leads to customer satisfaction
# #### 6. Online shopping provides wide variety of products listed into websites.
# #### 7. There is provision for complete product information.
# #### 8. From online shopping the monetary savings can be done.
#
# ## People agreed or have indifferent feeling on below attributes
# #### 1. 37% customer have indifferent feeling on Gratification on e-retailer
# #### 2. 32% of customer have indifferent feeling that shopping online fills the role.
# #### 3. 55% customer believes that online shopping give value for money.
#
# #### * Amazon being top player in the e-commerce business, is one of common Online_retailers_shopped by all customers.

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Web-page_layout'], palette='CMRmap')
plt.xticks(rotation=90)
print('Visual appealing web-page layout : \n',(df['Web-page_layout'].value_counts()))

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Variety_of_product'], palette='Greens')
plt.xticks(rotation=90)
print('\n Wild variety of product on offer: \n',(df['Variety_of_product'].value_counts()))

plt.show()
# Out:
# Visual appealing web-page layout :
#  Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Flipkart.com, Myntra.com                                        15
# Myntra.com                                                      15
# Amazon.in, Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Web-page_layout, dtype: int64
#
#  Wild variety of product on offer:
#  Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Complete/relavant info'], palette='PRGn')
plt.xticks(rotation=90)
print('Complete, relevant description information of products : \n',(df['Complete/relavant info'].value_counts()))

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Speed_of_website'], palette='PiYG_r')
plt.xticks(rotation=90)
print('\n Fast loading website speed of website and application: \n',(df['Speed_of_website'].value_counts()))

plt.show()
# Out:
# Complete, relevant description information of products :
#  Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete/relavant info, dtype: int64
#
#  Fast loading website speed of website and application:
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Reliability_of_application'], palette='PuBuGn_r')
plt.xticks(rotation=90)
print('Reliability of the website or application : \n',(df['Reliability_of_application'].value_counts()))

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Quickness'], palette='PuRd')
plt.xticks(rotation=90)
print('\n Quickness to complete purchase: \n',(df['Quickness'].value_counts()))

plt.show()
# Out:
# Reliability of the website or application :
#  Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability_of_application, dtype: int64
#
#  Quickness to complete purchase:
#  Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Payment_options'], palette='Spectral')
plt.xticks(rotation=90)
print('Availability of several payment options : \n',(df['Payment_options'].value_counts()))

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Delivery_Speed'], palette='RdYlBu_r')
plt.xticks(rotation=90)
print('\n Speedy order delivery: \n',(df['Delivery_Speed'].value_counts()))

plt.show()
# Out:
# Availability of several payment options :
#  Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Payment_options, dtype: int64
#
#  Speedy order delivery:
#  Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# ...

# %% [markdown]
# ## Observations:
#
# #### 1. Amazon and Flipkart are the online shopping applications/websites with good web-page layout, comprise of 32% of customer votes
# #### 2. 70% of customers say that wild variety of products are listed in Amazon and Flipkart
# #### 3. 15% of customers believe the reliability of amazon website is better followed by flipkart, myntra, paytm, snapdeal
# #### 4. Amazon has quickest purchase time as per customer feedback comprise of 28% of total feedback
# #### 5. Wide range of payment methods has to be provided by online websites/application in order to attract higher customer base.
# #### 6. In order to retain the customer, we have to work more on waiting period for delivery, which can be done by appointing more logistics option internally as well as externally.

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Privacy_of_customer_info'], palette='YlGn')
plt.xticks(rotation=90)
print('Privacy of customers information : \n',(df['Privacy_of_customer_info'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Financial_info_security'], palette='afmhot')
plt.xticks(rotation=90)
print('\nSecurity of customer financial information  : \n',(df['Financial_info_security'].value_counts())/269*100)

plt.show()
# Out:
# Privacy of customers information :
#  Amazon.in                                                       26.394052
# Amazon.in, Flipkart.com                                         20.074349
# Amazon.in, Flipkart.com, Myntra.com                              9.293680
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     8.921933
# Paytm.com                                                        6.691450
# Amazon.in, Paytm.com                                             5.576208
# Myntra.com                                                       5.576208
# Flipkart.com                                                     5.576208
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5.204461
# Amazon.in, Flipkart.com, Paytm.com                               4.089219
# Amazon.in, Flipkart.com, Snapdeal.com                            2.602230
# Name: Privacy_of_customer_info, dtype: float64
#
# Security of customer financial information  :
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Trustworthiness'], palette='YlGn')
plt.xticks(rotation=90)
print('Perceived Trustworthiness : \n',(df['Trustworthiness'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Online_assistance'], palette='afmhot')
plt.xticks(rotation=90)
print('\nPresence of online assistance through multi-channel : \n',(df['Online_assistance'].value_counts())/269*100)

plt.show()
# Out:
# Perceived Trustworthiness :
#  Amazon.in                                                       28.252788
# Amazon.in, Flipkart.com, Snapdeal.com                           13.382900
# Amazon.in, Myntra.com                                           13.011152
# Amazon.in, Flipkart.com                                         11.524164
# Flipkart.com                                                    10.037175
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                9.293680
# Myntra.com                                                       5.576208
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     4.832714
# Amazon.in, Flipkart.com, Paytm.com                               4.089219
# Name: Trustworthiness, dtype: float64
#
# Presence of online assistance through multi-channel :
#  Amazon.in, Flipkart.com, Myntra.com, Snapdeal    22.676580
# Amazon.in                                        22.304833
# Amazon.in, Flipkart.com                          14.498141
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['time_in_promotion_sales_period'], palette='bwr_r')
plt.xticks(rotation=90)
print('Longer time to get logged in (promotion, sales period) : \n',(df['time_in_promotion_sales_period'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Displaying_graphs_time'], palette='cividis_r')
plt.xticks(rotation=90)
print('\nLonger time in displaying graphics and photos (promotion, sales period) : \n',(df['Displaying_graphs_time'].value_counts())/269*100)

plt.show()
# Out:
# Longer time to get logged in (promotion, sales period) :
#  Amazon.in                                21.189591
# Paytm.com                                14.126394
# Amazon.in, Flipkart.com                  14.126394
# Myntra.com                               13.011152
# Amazon.in, Flipkart.com, Snapdeal.com    10.780669
# Snapdeal.com                              9.293680
# Flipkart.com, Paytm.com                   5.576208
# Flipkart.com, Paytm.com, Snapdeal.com     4.832714
# Amazon.in, Paytm.com                      4.089219
# Flipkart.com                              2.973978
# Name: time_in_promotion_sales_period, dtype: float64
#
# Longer time in displaying graphics and photos (promotion, sales period) :
#  Amazon.in, Flipkart.com                22.304833
# Amazon.in                              14.498141
# Myntra.com                             13.011152
# Snapdeal.com                           12.639405
# Myntra.com, Snapdeal.com                9.293680
# ...

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Design_change'], palette='bwr_r')
plt.xticks(rotation=90)
print('Change in website/Application design: \n',(df['Design_change'].value_counts())/269*100)

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Disruption_frequency'], palette='cividis_r')
plt.xticks(rotation=90)
print('\n Frequent disruption when moving from one page to another : \n',(df['Disruption_frequency'].value_counts())/269*100)

plt.show()
# Out:
# Change in website/Application design:
#  Amazon.in                   35.687732
# Paytm.com                   23.420074
# Amazon.in, Flipkart.com     16.728625
# Myntra.com                  11.152416
# Flipkart.com                 7.434944
# Snapdeal.com                 2.973978
# Flipkart.com, Myntra.com     2.602230
# Name: Design_change, dtype: float64
#
#  Frequent disruption when moving from one page to another :
#  Amazon.in                     19.702602
# Myntra.com                    19.330855
# Snapdeal.com                  18.215613
# Paytm.com                     14.498141
# Flipkart.com                   9.665428
# Amazon.in, Flipkart.com        9.293680
# Myntra.com, Snapdeal.com       5.204461
# Flipkart.com, Snapdeal.com     4.089219
# Name: Disruption_frequency, dtype: float64

# %%
plt.figure(figsize=(15,8), facecolor='white')
ax = plt.subplot(1,2,1)
sns.countplot(x=df['Efficiency_comparison'], palette='gnuplot2_r')
plt.xticks(rotation=90)
print('Website is as efficient as before : \n',(df['Efficiency_comparison'].value_counts()))

ax = plt.subplot(1,2,2)
sns.countplot(x=df['Recomendation_of_online_retailer'], palette='gist_earth_r')
plt.xticks(rotation=90)
print('\nWhich of the Indian online retailer would you recommend to a friend? : \n',(df['Recomendation_of_online_retailer'].value_counts()))

plt.show()
# Out:
# Website is as efficient as before :
#  Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Efficiency_comparison, dtype: int64
#
# Which of the Indian online retailer would you recommend to a friend? :
#  Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# ...

# %% [markdown]
# ## Observations:
# #### 1. Privacy of customers information: When customer uses online shopping, they will be sharing all the personal/private information to the retailers, Keeping the privacy of customer is one of toughest though most important thing which helps in building trust in customers
# #### 2. Financial information: shared by customer during payments will be saved in online store databases. Hence keeping the financial information safe makes the them reliable towards customer.
# #### 3. Trustworthiness: built up towards customer might be one of important reason to increase customer database
# #### 4. If customer who have made online shopping from any retailer, Resolving there issues wrt to product should be important so as to attract them again form online shopping, Presence of online assistance through multi-channel should be kept by online retailers.
# #### 5. To increase the number of customers attracting to online shopping, online retailers should focus on increasing sales promotion.
# #### 6. Online websites/applications should be having attractive product information and images/ graphics in order to make products more visible for shopping. While it should also be kept in mind to keep time constraints of loading the websites/images.
# #### 7. Online retailers will always be trying to bring any changes in there websites so change in website/Application design will be important to increase customer interaction.
# #### 8. Website/application efficiency are calculated by how fast the website can bring up the results, how big traffic it can hold with out being disrupted and how light the application is. It has to be designed keeping all the constraints in mind to be more efficient.
# #### 9  Finally recomendation is something one does when that product is really impressive and has been outstanding with all the competitors.
# We can see that amazon has got 79 individual votes out of 269, and flipkart has got 39 votes from the customer choosed.

# %% [markdown]
# ## Conclusion:
#
# Based on the above understanding, analysis, EDA steps and visualizations we could see find some insights about the online retail stores, how they have been working to improvise there customer activity, and increasing customer repeat purchase intention.
#
# 1. The gender ratio of male and female was unbalanced, there are more number of women who make online shopping then that of men, who are shopping since more than 3 years, most of customer use Mobile applications for online shopping using there mobile internet to connect to online retailers.
#
# 2. The sales of products could be increased by analysing the reason provided to abandon the bag, by increasing the quality of information that is being provided in the product information box, providing more benefits to the customers and discounts over the period of times, customer retention can be seen, which also helps in increasing the customer Loyalty towards the online retailers.
#
# 3. Online retailers should be more focused providing the best service to the customer base like providing clear and much relavant information for products or setting up the good website/application service which is handy in use with userfriendly interfaces.
#
# 4. Online retailers should be more focused on providing convenient mode of payments so that customer feels safe to share the private and financial informations for transactions and make sure the privacy retention of customer is the goal.
#
# 5. E-commerce businesses have to provide wild range of variety of combinations for the products which make the customer to choose which is best suitable for there use case, also make sure that products listed on the site are trust worthy and maintain quality. Customer also be provided with return and replacement policies.
#
# 6. Overall customer should be provided with such a service that he is coming back to us with all heart looking for the value for the money he spent on our products, such services create trustworthiness between customer and sellers.
#
# ### Looking at above surveys took between couple of the online retailers, Amazon has been the best customer friendly, reliable, user friendly, customer service focused company which has excellent customer assitance at hand to provide all the information, help needed by customer hence such environments attract huge customer bases and also less number of churns are seen.
#
# ### By the recomendations provided Amazon bagged 21% of overall upvotes which makes that amazon is leading in its own sector. Though there are some drawbacks like 'mode of payments' and 'Speed_of_website', 'website application ease' which company needs to work on to improvise there actions and attract more customers.
#
# ### Also company has been constantly focusing on providing customer benefits and discounts on products to attract huge base of customer.
